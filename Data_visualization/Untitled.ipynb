# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

flight_data = sns.load_dataset('flights')
flight_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Scatter plot
sns.scatterplot(data=flight_data, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# Making beautiful plots with styles
sns.set_style('darkgrid')

sns.lineplot(data=flight_data, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# Making beautiful plots with styles
sns.set_style('whitegrid')

sns.lineplot(data=flight_data, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.barplot(data=flight_data, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
diamond_data = sns.load_dataset('diamonds')
plt.subplot(1, 2, 1)
sns.countplot(x='carat', data=diamond_data)
plt.subplot(1,2,2)
sns.countplot(x='depth', data=diamond_data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='count'>

# %% [markdown]
# ### Subplot Need more information?

# %%
diamond_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df['tip_percentage'] = tips_df['tip']/ tips_df['total_bill']
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2        0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3        0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3        0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2        0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4        0.146808

# %%
sns.histplot(tips_df['tip_percentage'], binwidth=0.05)
# Out:
# <AxesSubplot:xlabel='tip_percentage', ylabel='Count'>

# %% [markdown]
# It would also be interesting to know if the tip percentage changes depending on the moment of the day,

# %%
sns.histplot(data=tips_df, x='tip_percentage', binwidth=0.05, hue='time')
# Out:
# <AxesSubplot:xlabel='tip_percentage', ylabel='Count'>

# %% [markdown]
# Another interesting metric is to know how much money in tips can the personnel expect depending on the day of the week.

# %%
sns.barplot(data=tips_df, x='day', y='tip', estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# Sometimes we want to understand how two variables play together to determine output. For example, how do the day of the week and the table size impact the tip percentage?

# %%
pivot = tips_df.pivot_table(index=['day'], 
                            columns=['size'], 
                            values='tip_percentage',
                           aggfunc=np.average)
pivot
# Out:
# size         1         2         3         4         5         6
# day
# Thur  0.181728  0.163935  0.144599  0.145515  0.121389  0.173706
# Fri   0.223776  0.168693  0.187735  0.117750       NaN       NaN
# Sat   0.231832  0.155289  0.151439  0.138289  0.106572       NaN
# Sun        NaN  0.180870  0.152662  0.153168  0.159839  0.103799

# %%
sns.heatmap(pivot)
# Out:
# <AxesSubplot:xlabel='size', ylabel='day'>
